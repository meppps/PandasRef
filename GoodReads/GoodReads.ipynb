# %% [markdown]
# # GoodReads - Part I
#
# ## Instructions
#
# * Read in the GoodReads CSV using Pandas
#
# * Remove unnecessary columns from the DataFrame so that only the following columns remain: `isbn`, `original_publication_year`, `original_title`, `authors`, `ratings_1`, `ratings_2`, `ratings_3`, `ratings_4`, and `ratings_5`
#
# * Rename the columns to the following: `ISBN`, `Publication Year`, `Original Title`, `Authors`, `One Star Reviews`, `Two Star Reviews`, `Three Star Reviews`, `Four Star Reviews`, and `Five Star Reviews`
#
# * Write the DataFrame into a new CSV file
#
# ## Hints
#
# * The base CSV file uses UTF-8 encoding. Trying to read in the file using some other kind of encoding could lead to strange characters appearing within the dataset.

# %%
# Import Dependencies
import pandas as pd

# %%
# Make a reference to the books.csv file path
df = pd.read_csv('books.csv')

# Import the books.csv file as a DataFrame
#df = pd.read_csv('..','Resources','books.csv')
df
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
newDf = df[["isbn","original_title","original_publication_year","authors","ratings_1","ratings_2","ratings_3","ratings_4","ratings_5"]]
# Only keep: "isbn", "original_publication_year", "original_title", "authors",
# "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"
newDf
# Out:
#             isbn                                     original_title  \
# 0      439023483                                   The Hunger Games
# 1      439554934           Harry Potter and the Philosopher's Stone
# 2      316015849                                           Twilight
# 3       61120081                              To Kill a Mockingbird
# 4      743273567                                   The Great Gatsby
# ...          ...                                                ...
# 9995   441019455                                         Bayou Moon
# 9996  067973371X                                   Means of Ascent
# 9997  039330762X                              The Mauritius Command
# 9998    61711527  Cinderella Ate My Daughter: Dispatches from th...
# 9999   375700455                                The First World War
#
#       original_publication_year                      authors  ratings_1  \
# 0                        2008.0              Suzanne Collins      66715
# ...

# %%
# Rename the headers to be more explanatory
newDf.rename(columns={"isbn":"ISBN","original_title":"Original Title","original_publication_year":"Original Publication Year",
                     "authors":"Authors","ratings_1":"One Star Ratings","ratings_2":"Two Star Ratings","ratings_3":"Three Star Ratings",
                      "ratings_4":"Four Star Ratings","ratings_5":"Five Star Ratings" })
# Out:
#             ISBN                                     Original Title  \
# 0      439023483                                   The Hunger Games
# 1      439554934           Harry Potter and the Philosopher's Stone
# 2      316015849                                           Twilight
# 3       61120081                              To Kill a Mockingbird
# 4      743273567                                   The Great Gatsby
# ...          ...                                                ...
# 9995   441019455                                         Bayou Moon
# 9996  067973371X                                   Means of Ascent
# 9997  039330762X                              The Mauritius Command
# 9998    61711527  Cinderella Ate My Daughter: Dispatches from th...
# 9999   375700455                                The First World War
#
#       Original Publication Year                      Authors  \
# 0                        2008.0              Suzanne Collins
# ...

# %%
# Push the remade DataFrame to a new CSV file
#newDf.to_csv("output/books_clean.csv")

# %%
summaryTable = newDf
len(summaryTable["Authors"].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Authors'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-b20429b7c7d4> in <module>
#       1 summaryTable = newDf
# ...
